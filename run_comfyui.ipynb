# %% [markdown]
# # Entorno de IA

# %%
# 1. Forzar la descarga limpia de ComfyUI
# !rm -rf ComfyUI
# !git clone https://github.com

# 2. Moverse al directorio del programa
# %cd /content/ComfyUI

# 3. Instalar las dependencias oficiales
# !pip install -r requirements.txt
# !pip install pyngrok xformers

# 4. Crear la estructura de carpetas necesarias
# !mkdir -p models/checkpoints

# 5. Descargar el modelo hiperrealista FLUX.1 Dev
# (Usamos el comando optimizado para evitar cortes de conexión)
# !aria2c --summary-interval=5 -x 16 -s 16 -k 1M https://huggingface.co -d models/checkpoints -o flux1-dev.safetensors

# 6. Lanzar ComfyUI con el túnel público activado
# !python main.py --dont-upcast-attention --listen --port 8188 --share
