# %% [markdown]
# # Entorno de IA Kink/BDSM con Filtro de Desnudos

# %%
# 1. Clonar ComfyUI desde GitHub al servidor de Google
# !git clone https://github.com
# %cd ComfyUI

# 2. Instalar dependencias del sistema y de Python
# !pip install torch torchvision torchaudio --index-url https://pytorch.org
# !pip install -r requirements.txt
# !pip install aiohttp Propcache

# 3. Descargar el modelo hiperrealista FLUX.1 Dev directo a la carpeta de modelos
# !wget -O models/checkpoints/flux1-dev.safetensors https://huggingface.co

# 4. Lanzar el programa y crear un túnel público seguro (Gradio/Cloudflare)
# Esto te dará una URL para entrar en línea y usar su API
# !python main.py --dont-upcast-attention --listen --port 8188 --share
